# %% [markdown]
# ### Declare Engine

# %%
import import_ipynb
from sqlalchemy import create_engine
engine = create_engine("sqlite:///sqlite.db", echo=True)

# %% [markdown]
# ### Create table

# %%
# %run s01_create_models.ipynb

# %%
Base.metadata.create_all(engine)
# Out:
# 2026-02-19 22:38:05,591 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-02-19 22:38:05,593 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("user_account")
# 2026-02-19 22:38:05,594 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-02-19 22:38:05,597 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("user_account")
# 2026-02-19 22:38:05,599 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-02-19 22:38:05,602 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("address")
# 2026-02-19 22:38:05,604 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-02-19 22:38:05,607 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("address")
# 2026-02-19 22:38:05,609 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-02-19 22:38:05,612 INFO sqlalchemy.engine.Engine
# CREATE TABLE user_account (
# 	id INTEGER NOT NULL,
# 	name VARCHAR(30) NOT NULL,
# 	fullname VARCHAR,
# 	PRIMARY KEY (id)
# )
#
#
# 2026-02-19 22:38:05,614 INFO sqlalchemy.engine.Engine [no key 0.00191s] ()
# ...
