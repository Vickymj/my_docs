# %% [markdown]
# # Python Assignment: 1

# %% [markdown]
# ### Data Types and Conversion

# %%
# 1. Write a Python program that takes an integer input and converts it into a float and a string. 
# Display all the three values.
# Example: Input: 10; Output: 10 (int), 10.0 (float), '10' (string)

# %%
# 2. Given two inputs, one as a float and the other as a string, convert them into integers and 
# add the two values.
# Example: Input: 12.5, '15'; Output: 27

# %%
# 3. Given two inputs number, give me the product of two numbers
# Example: Input: 10, 15; Output: 150

# %% [markdown]
# ### Formatted Strings

# %%
# 4. Write a Python program to display a user's first name and age using an f-string.
# Example: Input: 'John', 25; Output: "Hello John, you are 25 years old."

# %%
# 5. Given a number, display it with two decimal places using formatted strings.
# Example: Input: 45.6789; Output: "45.68"

# %%
# 6. Write a Python program that accepts a product name and price, and displays them in a formatted 
# string such that the price appears with a currency symbol.
# Example: Input: 'Apple', 1.5; Output: "Product: Apple, Price: $1.50"

# %% [markdown]
# ### Numbers and Operators

# %%
# 7. Write a Python program to calculate the square and cube of a number using arithmetic operators.
# Example: Input: 3; Output: 9 (square), 27 (cube)

# %%
# 8. Given three numbers, find the largest among them using comparison operators.
# Example: Input: 10, 25, 5; Output: 25

# %%
# 9. Write a Python program that takes two numbers and checks whether the first is divisible by the second.
# Example: Input: 10, 2; Output: True

# %%
# 10. Using logical operators, write a Python program that checks if a number is both positive and even.
# Example: Input: 4; Output: True

# %%
# 11. Write a Python program that calculates the area of a circle given the radius using the formula `area = πr^2`.
# Use 3.14 for π.
# Example: Input: 7; Output: 153.86

# %% [markdown]
# ### String and Number Methods

# %%
# 12. Write a Python program that accepts a string and prints the string in reverse.
# Example: Input: 'Hello'; Output: 'olleH'

# %%
# 13. Write a Python program that convert string to the upper case
#Example: Input 'Hello'; Output:'HELLO'

# %%
# 14. Given a number as input, use string methods to count how many digits the number contains.
# Example: Input: 12345; Output: 5 digits

# %%
# 15. Write a Python program to check if a string starts with a specific character (case insensitive).
# Example: Input: 'Python', 'p'; Output: True

# %% [markdown]
# ### Collections: Lists, Dictionaries, Tuples, Sets

# %%
# 16. Write a Python program to create a list of 5 numbers, sort the list in descending order, 
# and display the sorted list.
# Example: Input: [4, 2, 9, 1, 5]; Output: [9, 5, 4, 2, 1]

# %%
# 17. Write a Python program that adds a key-value pair to a dictionary and then updates the value of the key.
# Example: Input: {'name': 'John'}; Add key 'age', Update 'name' to 'Jane'; Output: {'name': 'Jane', 'age': 25}

# %%
# 18. Given a tuple of 4 elements, write a Python program to unpack the tuple into four variables and display them.
# Example: Input: (10, 20, 30, 40); Output: 10, 20, 30, 40

# %%
# 19. Write a Python program to remove duplicates from a given list by converting it to a set.
# Example: Input: [1, 2, 3, 2, 4, 1]; Output: {1, 2, 3, 4}
