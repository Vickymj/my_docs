# %% [markdown]
# # Python Assignment: 2

# %% [markdown]
# ### 1. Lists
# 1. Create a list of 10 numbers and print the list.
# 2. Append an element to a list and print the updated list.
# 3. Remove an element from the list and print the updated list.
# 4. Sort the list in ascending order and print it.
# 5. Reverse the list and print it.
# 6. Slice the list to print only the first 5 elements.

# %%
# Write your Ans here

# %% [markdown]
# ### 2. Dictionaries
# 7. Create a dictionary of 5 key-value pairs and print the dictionary.
# 8. Add a new key-value pair to the dictionary and print the updated dictionary.
# 9. Update the value of an existing key and print the updated dictionary.
# 10. Delete a key from the dictionary and print the updated dictionary.
# 11. Loop through the dictionary and print all keys and values.

# %%
# Write your Ans here

# %% [markdown]
# ### 3. Loops and If Conditions
# 12. Write a `for` loop to print all the numbers from 1 to 20.
# 13. Write a `for` loop to print only the even numbers from 1 to 20.
# 14. Write an `if-else` condition to check if a number is positive, negative, or zero.
# 15. Write a `while` loop to print the numbers from 5 down to 1.

# %%
# Write your Ans here

# %% [markdown]
# ### 4. Functions
# 16. Write a function to calculate the square of a number.
# 17. Write a function that takes two numbers as input and returns their sum.

# %%
# Write your Ans here

# %% [markdown]
# ### 5. Lambda Functions
# 18. Write a lambda function to add 10 to a given number.
# 19. Write a lambda function to find the product of two numbers.
# 20. Write a lambda function to filter even numbers from a list.

# %%
# Write your Ans here
